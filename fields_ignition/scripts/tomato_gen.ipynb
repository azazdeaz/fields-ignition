# %%
import rospy
import numpy as np
from cookiecutter.main import cookiecutter
import collections
from pathlib import Path
import json

# %%
def get_param(name, default):
    try:
        value = rospy.get_param(name, default)
    except ConnectionRefusedError:
        value = default
    print('param "{}" = "{}"'.format(name, value))
    return value

SEED = int(get_param('~seed', '178'))
WORLD_NAME = get_param('~world_name', 'tomato_field')
MODEL_NAME_PREFIX = get_param('~model_name_prefix', 'tomato')
OUT_PATH = Path(get_param('~out_path', Path.cwd() / '../generated/test01')).resolve()
MODEL_TEMPLATE = Path(get_param('~model_template', Path.cwd() / '../templates/tomato_model')).resolve()
WORLD_TEMPLATE = Path(get_param('~world_template', Path.cwd() / '../templates/tomato_world')).resolve()
ROW_COUNT = int(get_param('~row_count', '2'))
ROW_LENGTH = int(get_param('~row_length', '3'))
ROW_DIST = float(get_param('~row_dist', '2.0'))
CROP_DIST = float(get_param('~crop_dist', '1.4'))

np.random.seed(SEED)
# Out:
# param "~seed" = "178"
# param "~world_name" = "tomato_field"
# param "~model_name_prefix" = "tomato"
# param "~out_path" = "/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/scripts/../generated/test01"
# param "~model_template" = "/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/scripts/../templates/tomato_model"
# param "~world_template" = "/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/scripts/../templates/tomato_world"
# param "~row_count" = "2"
# param "~row_length" = "3"
# param "~row_dist" = "2.0"
# param "~crop_dist" = "1.4"

# %%
class Markers:
    markers = []
    last_id = 0

    @staticmethod
    def next_id():
        Markers.last_id += 1
        return Markers.last_id

    @staticmethod
    def reset():
        Markers.markers = []
    
    @staticmethod
    def add_plant(x, y, z):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'PLANT',
            'id': id,
            'translation': [x, y, z]
        })
        return id
    

    @staticmethod
    def add_fruit(x, y, z, plant_id):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'FRUIT',
            'id': id,
            'translation': [x, y, z],
            'plant_id': plant_id
        })
        return id
    
    @staticmethod
    def dumps():
        return json.dumps(Markers.markers, indent=4)

# %%
models = {'list': []}
Markers.reset()

for x in range(ROW_COUNT):
    for y in range(ROW_LENGTH):
        model_name = 'tomato_{}'.format(x * ROW_LENGTH + y)

        cookiecutter(str(MODEL_TEMPLATE),
             output_dir=str(OUT_PATH), 
             overwrite_if_exists=True, 
             no_input=True,
             extra_context={'world_name': WORLD_NAME, 'model_name': model_name})

        x_pos, y_pos, z_pos = x * ROW_DIST, y * CROP_DIST, 0
        models['list'].append({
            'model': model_name,
            'name': model_name,
            'pose': '{} {} 0 0 0 0'.format(x_pos, y_pos)
        })
        seed = np.random.randint(10000)
        dir = (OUT_PATH / WORLD_NAME / model_name).resolve()
        dir_blender = (Path.cwd() / '../blender').resolve()
        blend = str(dir_blender / 'tomato_gen.blend')
        script = str(dir_blender / 'tomato_gen.py')
        ! blender $blend --background --python $script -- --model_dir $dir --seed $seed

        plant_id = Markers.add_plant(x_pos, y_pos, z_pos)
        with open(dir / 'markers.json') as markers_file:
            plant_markers = json.load(markers_file)
            for marker in plant_markers:
                if marker['marker_type'] == 'FRUIT':
                    Markers.add_fruit(
                        marker['translation'][0] + x_pos,
                        marker['translation'][1] + y_pos,
                        marker['translation'][2] + z_pos,
                        plant_id
                    )
            

cookiecutter(str(WORLD_TEMPLATE),
             output_dir=str(OUT_PATH), 
             overwrite_if_exists=True, 
             no_input=True,
             extra_context={'world_name': WORLD_NAME, 'models': models})

with open(OUT_PATH / WORLD_NAME / 'markers.json', 'w') as outfile:
    json.dump(Markers.markers, outfile, indent=4, sort_keys=True)
# Out:
# pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206']]
# [bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206']]
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_0/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
# Info: Deleted 7 object(s)
# Info: Deleted 7 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
# Blender 2.90.1 (hash 3e85bb34d0d7 built 2020-09-23 08:34:47)
# Read prefs: /home/azazdeaz/.config/blender/2.90/config/userpref.blend
# /run/user/1000/snap.blender/gvfs/ non-existent directory
# found bundled python: /snap/blender/47/2.90/python
# Read blend: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/blender/tomato_gen.blend
# Namespace(model_dir='/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_1', seed=6252)
# selected model is AG15_8
# bpy.context.selected_objects [bpy.data.objects['AG15_8.001'], bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206']]
# [bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206']]
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_1/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
# Info: Deleted 7 object(s)
# Info: Deleted 7 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
# Blender 2.90.1 (hash 3e85bb34d0d7 built 2020-09-23 08:34:47)
# Read prefs: /home/azazdeaz/.config/blender/2.90/config/userpref.blend
# /run/user/1000/snap.blender/gvfs/ non-existent directory
# found bundled python: /snap/blender/47/2.90/python
# Read blend: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/blender/tomato_gen.blend
# Namespace(model_dir='/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_2', seed=9993)
# selected model is AG15_4
# bpy.context.selected_objects [bpy.data.objects['AG15_4.001'], bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193']]
# [bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193']]
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt4.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_2/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
# Info: Deleted 9 object(s)
# Info: Deleted 9 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
# Blender 2.90.1 (hash 3e85bb34d0d7 built 2020-09-23 08:34:47)
# Read prefs: /home/azazdeaz/.config/blender/2.90/config/userpref.blend
# /run/user/1000/snap.blender/gvfs/ non-existent directory
# found bundled python: /snap/blender/47/2.90/python
# Read blend: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/blender/tomato_gen.blend
# Namespace(model_dir='/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_3', seed=4499)
# selected model is AG15_3
# bpy.context.selected_objects [bpy.data.objects['AG15_3.001']]
# []
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_3/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
# Info: Deleted 6 object(s)
# Info: Deleted 6 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
# Blender 2.90.1 (hash 3e85bb34d0d7 built 2020-09-23 08:34:47)
# Read prefs: /home/azazdeaz/.config/blender/2.90/config/userpref.blend
# /run/user/1000/snap.blender/gvfs/ non-existent directory
# found bundled python: /snap/blender/47/2.90/python
# Read blend: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/blender/tomato_gen.blend
# Namespace(model_dir='/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_4', seed=2318)
# selected model is AG15_7
# bpy.context.selected_objects [bpy.data.objects['AG15_7.001'], bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206'], bpy.data.objects['pose_fruit.207'], bpy.data.objects['pose_fruit.208'], bpy.data.objects['pose_fruit.209'], bpy.data.objects['pose_fruit.210'], bpy.data.objects['pose_fruit.211'], bpy.data.objects['pose_fruit.212'], bpy.data.objects['pose_fruit.213'], bpy.data.objects['pose_fruit.214'], bpy.data.objects['pose_fruit.215']]
# [bpy.data.objects['pose_fruit.181'], bpy.data.objects['pose_fruit.182'], bpy.data.objects['pose_fruit.183'], bpy.data.objects['pose_fruit.184'], bpy.data.objects['pose_fruit.185'], bpy.data.objects['pose_fruit.186'], bpy.data.objects['pose_fruit.187'], bpy.data.objects['pose_fruit.188'], bpy.data.objects['pose_fruit.189'], bpy.data.objects['pose_fruit.190'], bpy.data.objects['pose_fruit.191'], bpy.data.objects['pose_fruit.192'], bpy.data.objects['pose_fruit.193'], bpy.data.objects['pose_fruit.194'], bpy.data.objects['pose_fruit.195'], bpy.data.objects['pose_fruit.196'], bpy.data.objects['pose_fruit.197'], bpy.data.objects['pose_fruit.198'], bpy.data.objects['pose_fruit.199'], bpy.data.objects['pose_fruit.200'], bpy.data.objects['pose_fruit.201'], bpy.data.objects['pose_fruit.202'], bpy.data.objects['pose_fruit.203'], bpy.data.objects['pose_fruit.204'], bpy.data.objects['pose_fruit.205'], bpy.data.objects['pose_fruit.206'], bpy.data.objects['pose_fruit.207'], bpy.data.objects['pose_fruit.208'], bpy.data.objects['pose_fruit.209'], bpy.data.objects['pose_fruit.210'], bpy.data.objects['pose_fruit.211'], bpy.data.objects['pose_fruit.212'], bpy.data.objects['pose_fruit.213'], bpy.data.objects['pose_fruit.214'], bpy.data.objects['pose_fruit.215']]
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15frt3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_4/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
# Info: Deleted 9 object(s)
# Info: Deleted 9 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
# Blender 2.90.1 (hash 3e85bb34d0d7 built 2020-09-23 08:34:47)
# Read prefs: /home/azazdeaz/.config/blender/2.90/config/userpref.blend
# /run/user/1000/snap.blender/gvfs/ non-existent directory
# found bundled python: /snap/blender/47/2.90/python
# Read blend: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/blender/tomato_gen.blend
# Namespace(model_dir='/home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_5', seed=2587)
# selected model is AG15_2
# bpy.context.selected_objects [bpy.data.objects['AG15_2.001']]
# []
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo2.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15blo3.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15brn1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef1.tif
# Collada export: image does not exist:
# //tomato_models/Models/AG15lef2.tif
# Collada export to: /home/azazdeaz/repos/fields_ignition/src/packs/fields_ignition/generated/test01/tomato_field/tomato_5/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
# Info: Deleted 6 object(s)
# Info: Deleted 6 object(s)
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001190 MB
